# %% [markdown]
# # Questions on Sets

# %% [markdown]
# ## 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

# %%
s1 = {1,2,3,4,1}
print(s1)     #obesrvation is : output come in Curly Bracket{}
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ## 2. (Easy) Create an empty set using correct syntax and add 3 numbers using add().

# %%
# e={}   this is not set this is so we can add anything from this techique
e=set()
e.add(1)
e.add(2)
e.add(3)

e.update([6,7,8])    # using update
print(e)
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# ## 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().

# %%
s = {10, 20, 30}
s.update([40, 50, 60])
print(s) #here itrate is from 
s        #here is accending order
# Out:
# {40, 10, 50, 20, 60, 30}
# {10, 20, 30, 40, 50, 60}

# %% [markdown]
# ## 4. (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

# %%
s = {10, 20, 30, 40} 
s.remove(10)       # if number is not present then show error    
s.discard(10)      # if number is not present then not show error 
s
# Out:
# {20, 30, 40}

# %% [markdown]
# ## 5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

uni = A.union(B)
inter =A.intersection(B)
diff =A.difference(B)

print(f"union value is {uni}.")
print(f"intersection value is {inter}.")
print(f"diffrence value is {diff}.")
# Out:
# union value is {1, 2, 3, 4, 5, 6}.
# intersection value is {3, 4}.
# diffrence value is {1, 2}.

# %% [markdown]
# ## 6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.

# %%
s = {10, 20, 30, 40}

print("25"in s)
# Out:
# False

# %% [markdown]
# ## 7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.

# %%
lst = [1, 2, 2, 3, 4, 4, 5]
print("length of this list : ",len(lst))
lst = set(lst)
print("length of this set : ",len(lst))
# Out:
# length of this list :  7
# length of this set :  5

# %% [markdown]
# ## 8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.

# %%
sets=set()

n1 = int(input("Enter 1st Number: "))
n2 = int(input("Enter 2st Number: "))
n3 = int(input("Enter 3st Number: "))
n4 = int(input("Enter 4st Number: "))
n5 = int(input("Enter 5st Number: "))

sets.add(n1)
sets.add(n2)
sets.add(n3)
sets.add(n4)
sets.add(n5)
sets
# Out:
# Enter 1st Number:  44
# Enter 2st Number:  55
# Enter 3st Number:  55
# Enter 4st Number:  44
# Enter 5st Number:  7
# {7, 44, 55}

# %% [markdown]
# ## 9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.

# %%
A = {1, 2, 3}
B = {3, 4, 5}

print("Element that are inA but not in B: ",A.difference(B))
# Out:
# Element that are inA but not in B:  {1, 2}

# %% [markdown]
# ## 10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?

# %%
sets={4,1}
#sets.add([1,2,3])  # using add not in set 
sets.update([1,2,3])  #using update we can add list
sets
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # If Statement Questions (11-20)

# %% [markdown]
# ## 11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".

# %%
age =int(input("Enter your Age: "))

if age>=18:
         print("You are eligible to vote.")
# Out:
# Enter your Age:  55
# You are eligible to vote.

# %% [markdown]
# ## 12. (Easy) Take a number and check if it is positive, negative, or zero using if.

# %%
no =int(input("Enter a number: "))

if no > 0:
    print("Number is Positive")

if no < 0:
    print("Number is Negative")

if no == 0:
    print("Number is Zero")
# Out:
# Enter a number:  55
# Number is Positive

# %% [markdown]
# ## 13. (Medium) Take two numbers and print the larger one using if.

# %%
n1 =int(input("Enter first number: "))
n2 =int(input("Enter secound number: "))

if n1>n2:
    print("First Number is Large.")

if n1<n2:
    print("Secound Number is Large.")
    
if n1==n2:
    print("Number is Equal.")
# Out:
# Enter first number:  55
# Enter secound number:  5
# First Number is Large.

# %% [markdown]
# ## 14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using if statement.

# %%
char= (input("Enter one character: "))
char = char.lower()
if char == "a" or char == "e" or char == "i" or char == "o" or char == "u":   # using assignmental operator
          print("Yes this is Vowel.")                                          
if char in "aeiou":                                         # using in operation
    print(f"{char} is Vowel.")
# Out:
# Enter one character:  A
# Yes this is Vowel.
# a is Vowel.

# %% [markdown]
# ## 15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else → Fail.

# %%
marks=int(input("Enter a Marks: "))

if marks >= 90:
    print("Grade:A")
          
if marks >= 80:
    print("Grade:B")
          
if marks >= 70:
    print("Grade:C")
          
if marks < 70:
    print("Grade:Fail")
# Out:
# Enter a Marks:  70
# Grade:C

# %% [markdown]
# ## 16. (Hard) Take three numbers and print the largest one using if.

# %%
n1 =int(input("Enter first number: "))
n2 =int(input("Enter secound number: "))
n3 =int(input("Enter third number: "))

if n1 > n2 and n1 > n3:
    print("Number First is Largest.")

if n2 > n1 and n2 > n3:
    print("Number Secound is Largest.")

if n3 > n2 and n3 > n1:
    print("Number Third is Largest.")

if n1 == n2 and n1 == n3 and n2 == n3:
    print("Number is Equal.")
# Out:
# Enter first number:  5
# Enter secound number:  8
# Enter third number:  1
# Number Secound is Largest.

# %% [markdown]
# ## 17. (Hard) Take a number and check if it is even and greater than 50.

# %%
n1 =int(input("Enter first number: "))

if n1 % 2 == 0 and n1 > 50 :
    print("Number is Even and Greater than 50")

if n1 % 2 == 0 :
    print("Number is Even .")

if n1 > 50 :
    print("Greater than 50")
# Out:
# Enter first number:  200
# Number is Even and Greater than 50
# Number is Even .
#  Greater than 50

# %% [markdown]
# ## 18. (Hard) Take username and password. If username == "admin" and password =="1234", print "Login Successful", else "Login Failed".

# %%
username =input("Enter Your Username: ")
password =input("Enter Password: ")

if username == "admin" and password =="1234" :
    print("Login Successful")
else:
    print("Login Failed.")
# Out:
# Enter Your Username:  admin
# Enter Password:  4568
# Login Failed.

# %% [markdown]
# ## 19. (Hard) Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a Leap Year.")
else:
    print(f"{year} is Not a Leap Year.")
# Out:
# Enter a year:  2245
# 2245 is Not a Leap Year.

# %% [markdown]
# ## 20. (Hard) Take three sides of a triangle and check if they can form a valid triangle(sum of any two sides > third side

# %%
s1 =int(input("Enter first Side: "))
s2 =int(input("Enter secound Side: "))
s3 =int(input("Enter third Side: "))

if s1 + s2 > s3 and s2 + s3 > s1 and s1 + s3 > s4 :
    print("Valid Trangle")
else:
    print("Unvalid Trinagle")
# Out:
# Enter first Side:  2
# Enter secound Side:  3
# Enter third Side:  5
# Unvalid Trinagle

# %% [markdown]
# ## 1. (Hard) Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.

# %%
n1 =int(input("Enter first number: "))
n2 =int(input("Enter secound number: "))
n3 =int(input("Enter third number: "))

if n1 > n2 and n1 > n3:
    print("Number First is Largest.")

if n2 > n1 and n2 > n3:
    print("Number Secound is Largest.")

if n3 > n2 and n3 > n1:
    print("Number Third is Largest.")

if n1 == n2 and n1 == n3 and n2 == n3:
    print("Number is Equal.")
# Out:
# Enter first number:  55
# Enter secound number:  5
# Enter third number:  4
# Number First is Largest.

# %% [markdown]
# ## 2. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a Leap Year.")
else:
    print(f"{year} is Not a Leap Year.")
# Out:
# Enter a year:  2025
# 2025 is Not a Leap Year.

# %% [markdown]
# ## 3. (Hard) Take three sides of a triangle as input. Check if they can form a valid triangle (sum of any two sides must be greater than the third side). If valid, also print the type (Equilateral, Isosceles, or Scalene).

# %%
#s1 == s2 == s3
#s1 == s2 or s2 == s3 or s1 == s3
#s1 != s2 and s2 != s3 and s1 != s3

s1 =int(input("Enter first Side: "))
s2 =int(input("Enter secound Side: "))
s3 =int(input("Enter third Side: "))

if s1 + s2 > s3 and s2 + s3 > s1 and s1 + s3 > s2 :
    print("Valid Trangle")
else:
    print("Unvalid Trinagle")

if s1 == s2 == s3 :
    print("Tringle is Equilateral")

if s1 == s2 or s2 == s3 or s1 == s3 :
    print("Tringle is Isosceles")

if s1 != s2 and s2 != s3 and s1 != s3 :
    print("Tringle is Scalene")
# Out:
# Enter first Side:  5
# Enter secound Side:  5
# Enter third Side:  5
# Valid Trangle
# Tringle is Equilateral
# Tringle is Isosceles

# %% [markdown]
# ## 4. (Hard) Take a student's marks in 5 subjects. Calculate percentage and print grade according to these rules:• 90 or above → A+• 80–89 → A• 70–79 → B• 60–69 → C Below 60 → Fail Also print "Passed with Distinction" if percentage >= 75.

# %%
marks1=int(input("Enter 1 Marks: "))
marks2=int(input("Enter 2 Marks: "))
marks3=int(input("Enter 3 Marks: "))
marks4=int(input("Enter 4 Marks: "))
marks5=int(input("Enter 5 Marks: "))


per = ((marks1 + marks2 + marks3 + marks4 +marks5 )/500)*100
print("Percentage:",per)

if per >= 90:
    print("Grade:A+")
          
if per >= 80 and per <= 89:
    print("Grade:A")
          
if per >= 70 and per <=79:
    print("Grade:B")

if per >= 60 and per <=69:
    print("Grade:C")

if marks < 60:
    print("Grade:Fail")
# Out:
# Enter 1 Marks:  50
# Enter 2 Marks:  64
# Enter 3 Marks:  89
# Enter 4 Marks:  99
# Enter 5 Marks:  87
# Percentage: 77.8
# Grade:B
