# %% [markdown]
# # Python Built-in Functions

# %% [markdown]
# # 1. Type / Info Functions (Questions 1-5)

# %% [markdown]
# ## 1. What will type(10) and type(3.14) return? What is the difference?

# %%
print(type(10))
print(type(3.14))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## 2. What is the output of len("Python"), len([1,2,3,4]), and len((10,20))?

# %%
print(len("Python"))
print( len([1,2,3,4]))
print(len((10,20)))
# Out:
# 6
# 4
# 2

# %% [markdown]
# ## 3. Explain what id(5) does. Why do two variables with the same value sometimes have the same id() and sometimes different?

# %%
print(id(5))
print(id(5))
print(id(5))
print(id(5))
print(id(5))

# because every variable have there own address
# Out:
# 140734263567400
# 140734263567400
# 140734263567400
# 140734263567400
# 140734263567400

# %% [markdown]
# ## 4. What is the difference between type() and isinstance()? Give an example.

# %%
a = 10
b = 2.2


print(type(a))             # check type of that variable
print(type(a) == int)      

print(isinstance(b,float))    # check object is belong to class or subclass and return ans in True and false
print(isinstance(a, int))
# Out:
# <class 'int'>
# True
# True
# True

# %% [markdown]
# ## 5. Predict the output: print(len([[1,2],[3,4]]))

# %%
 print(len([[1,2],[3,4]]))
# Out:
# 2

# %% [markdown]
# # 2. Number Functions (Questions 6-12)

# %% [markdown]
# ## 6. What is the output of abs(-25) and abs(7.8)?

# %%
print(abs(-25))
print(abs(7.8))
# Out:
# 25
# 7.8

# %% [markdown]
# ## 7. What does round(3.678, 2) return? What about round(3.5) and round(2.5)?

# %%
print(round(3.678, 2))
print(round(3.5))
print(round(2.5))
# Out:
# 3.68
# 4
# 2

# %% [markdown]
# ## 8. Calculate pow(3, 4) and pow(2, 3, 5) (with modulo). What is the purpose of the third argument?

# %%
print(pow(3,4))     #here 3 is valuse and 4 is power
print(pow(2,3,5))   # here 2 value and 3 is power and 5 is module ans is remainder
# Out:
# 81
# 3

# %% [markdown]
# ## 9.Find the output: min(10, 5, 8, 3) and max(-1, -5, 0)

# %%
print(min(10,5,8,3))
print(max(-1,-5,0))
# Out:
# 3
# 0

# %% [markdown]
# ## 10.What will sum([1, 2, 3, 4, 5]) return? Can sum() work on a list of strings?

# %%
print(sum([1, 2, 3, 4, 5]))
print(sum("ritesh","girhe"))   #TypeError: sum() can't sum strings [use ''.join(seq) instead]
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(sum([1, 2, 3, 4, 5]))
# ----> 2 print(sum("ritesh","girhe"))
#
# TypeError: sum() can't sum strings [use ''.join(seq) instead]

# %% [markdown]
# ## 11.What is the difference between max() and sorted() when applied to a list?

# %%
lst=[78,45,12,63,96,258]
print(max(lst))
print(sorted(lst))
# Out:
# 258
# [12, 45, 63, 78, 96, 258]

# %% [markdown]
# ## 12.Predict: sum(range(1, 11))

# %%
sum(range(1, 11))
# Out:
# 55

# %% [markdown]
# ## 3. Input / Output (Questions 13-15)

# %% [markdown]
# ## 13.What is the difference between print("Hello") and print("Hello", end='')?

# %%
print("Hello", end=' ')  # here is cuser or output print is not move to next line because we write at end one space
print("Hello") 
print("Hello", end='')
# Out:
# Hello Hello
# Hello

# %% [markdown]
# ## 14.Explain how input() works. How do you take integer input from the user?

# %%
# here we take only input not specified it is num,string,list etc 
input()  # use to take a input from user 

# here we specified it is a int 
take_input =int(input("Enter a nunber: "))
# Out:
#  Ritesh
# Enter a nunber:  4568

# %% [markdown]
# ## 15.Write code using input() to take name and age from user and print a message.

# %%
name = str(input("Enter your Name : "))
age = int(input("Enter your Age : "))

print(f"Hi,{name} your age is {age}.")
# Out:
# Enter your Name :  Ritesh
# Enter your Age :  22
# Hi,Ritesh your age is 22.

# %% [markdown]
# # 4. Type Conversion (Questions 16-22)

# %% [markdown]
# ## 16.Convert the string "100" to integer and float. What happens if you do int("abc")?

# %%
a = "100"
print(int(a))   # converted into int

float(a)  # converted into float
# Out:
# 100
# 100.0

# %% [markdown]
# ## 17.What will str(500) and list("hello") return?

# %%
print(str(500))
print(list("hello"))
# Out:
# 500
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# ## 18.Convert the tuple (1,2,3) to a list and then to a set. What will be the output?

# %%
tupl = (1,2,3)
print(tupl)
print(list(tupl))
print(set(tupl))
# Out:
# (1, 2, 3)
# [1, 2, 3]
# {1, 2, 3}

# %% [markdown]
# ## 19.What is the output of tuple([1,2,2,3])?

# %%
tupl = ([1,2,2,3])  # [1,2,2,3] this list is one single value
tupl
# Out:
# [1, 2, 2, 3]

# %% [markdown]
# ## 20.Explain why set([1,1,2,2,3]) returns {1,2,3}.

# %%
set =([1,1,2,2,3])   # return [1, 1, 2, 2, 3] because this is work as tuple
st ={1,1,2,2,3}      # this work as set
print(set)
print(st)
# Out:
# [1, 1, 2, 2, 3]
# {1, 2, 3}

# %% [markdown]
# ## 21.What happens when you do bool(0), bool(""), bool([])?

# %%
print(bool(0))
print(bool(""))
print(bool([]))
# Out:
# False
# False
# False

# %% [markdown]
# ## 22.Convert range(5) into a list. What is the result?

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# # 5. Sequence Functions (Questions 23-27)

# %% [markdown]
# ## 23.What is the output of list(range(5)), list(range(2,10,2))?

# %%
print(list(range(5)))        # here print range fron index 0 to 4
print(list(range(2,10,2)))   #here 2 is step that show skip 2
# Out:
# [0, 1, 2, 3, 4]
# [2, 4, 6, 8]

# %% [markdown]
# ##  24.What does sorted([5,1,3,2]) return? Does it modify the original list?

# %%
#sorted([5,1,3,2])
lst = [5,1,3,2]
print(sorted(lst))  # here sored print
print(lst)          # here original print
# Out:
# [1, 2, 3, 5]
# [5, 1, 3, 2]

# %% [markdown]
# ## 25.Explain reversed([1,2,3,4]). How do you convert it to a list?

# %%
lst =[1,2,3,4]
list(reversed(lst))
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# ## 26.What is the difference between sorted() and reversed()?

# %%
lst = [5,1,3,2]
print(sorted(lst))
list(reversed(lst))
# Out:
# [1, 2, 3, 5]
# [2, 3, 1, 5]

# %% [markdown]
# ## 27.Predict: list(reversed("Python"))

# %%
list(reversed("Python"))
# Out:
# ['n', 'o', 'h', 't', 'y', 'P']

# %% [markdown]
# # 6. Iteration Helpers (Questions 28-31)

# %% [markdown]
# ## 28.What is the output of list(enumerate(["a","b","c"]))?

# %%
list(enumerate(["a","b","c"]))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %% [markdown]
# ## 29.Explain how zip([1,2,3], ['a','b','c']) works. What if lists have different lengths?

# %%
list(zip([1,2,3,4], ['a','b','c']))   # if list have extra lengths then no print that value
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %% [markdown]
# ## 30.Write code using enumerate() to print index and value from fruits = ["apple","banana","cherry"].

# %%
fruits = ["apple","banana","cherry"]
list(enumerate(fruits))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cherry')]

# %% [markdown]
# ## 31.What will dict(zip(['name','age'], ['Sumit', 25])) return?

# %%
dict(zip(['name','age'], ['Sumit', 25]))
# Out:
# {'name': 'Sumit', 'age': 25}

# %% [markdown]
# # 7. Logical Functions (Questions 32-35)

# %% [markdown]
# ## 32.What is the output of all([True, True, False]) and any([False, False, True])?

# %%
print(all([True, True, False]))
print(any([False, False, True]))
# Out:
# False
# True

# %% [markdown]
# ## 33.Explain a practical use case of all() and any() with a list of conditions.

# %%
# all() : if one is case is wrong 
# any() : if one case is correct

# %% [markdown]
# ## 34.Predict: all([]) and any([]) — Why?

# %%
print(all([]))
print(any([]))
# Out:
# True
# False

# %% [markdown]
# ## 35.How can you use any() to check if any number in a list is even?

# %%
numbers = [3, 7, 9, 12, 15]

result = any(num % 2 == 0 for num in numbers)

print(result)
# Out:
# True
