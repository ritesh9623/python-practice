# %% [markdown]
# ## 1.Write a lambda function to return the square of a number.

# %%
square = lambda x : x**2
print(square(5))
# Out:
# 25

# %% [markdown]
# ## 2.Write a lambda function to return the cube of a number.

# %%
cube = lambda x : x**3
print(cube(4))
# Out:
# 64

# %% [markdown]
# ## 3.Write a lambda function to add two numbers.

# %%
add = lambda x,y : x+y
print(add(10,20))
# Out:
# 30

# %% [markdown]
# ## 4.Write a lambda function to find the maximum of two numbers.

# %%
largest=lambda x,y : (f"first is Larger:{x}") if x > y else (f"secound is larger: {y}")
largest(50,20)
# Out:
# 'first is Larger:50'

# %% [markdown]
# ## 5.Write a lambda function that returns "Even" if a number is even; otherwise "Odd".

# %%
even_odd=lambda x : (f"Even:{x}") if x % 2 == 0 else (f"Odd: {x}")
even_odd(9)
# Out:
# 'Odd: 9'

# %% [markdown]
# ## 6.Use map() with lambda to square every element of a list.

# %%
num = [ 1,2,3,5,4]

squ = list(map(lambda x : x**2,num))
squ
# Out:
# [1, 4, 9, 25, 16]

# %% [markdown]
# ## 7.Use filter() with lambda to keep only even numbers.

# %%
num = [ 1,2,3,4,5,6]
even = list(filter(lambda x: x % 2 == 0,num))
even
# Out:
# [2, 4, 6]

# %% [markdown]
# ## 8.Use filter() with lambda to keep numbers greater than 50.

# %%
num = [44,45,55,70]
larger = list(filter(lambda x : x > 50,num))
larger
# Out:
# [55, 70]

# %% [markdown]
# ## 9.Sort a list of numbers in ascending order using lambda.

# %%
num = [9,5,1,8,2]
order = sorted(num, key=lambda x: x)
print(order)

#numbers = [23, 1, 45, 3, 12, 7]
#numbers.sort(key=lambda x: x)
#print(numbers)
# Out:
# [1, 2, 5, 8, 9]

# %% [markdown]
# ## 10.Sort a list of numbers in descending order using lambda.

# %%
num = [9,5,1,8,2]
order = sorted(num, key=lambda x: x,reverse = True)
print(order)
# Out:
# [9, 8, 5, 2, 1]

# %% [markdown]
# ## 11.Use reduce() with lambda to find the sum of all numbers.

# %%
from functools import reduce

result = reduce(lambda x,y: x+y, [10,20,30,40])

print(result)
# Out:
# 100

# %% [markdown]
# ## 12.Use reduce() with lambda to find the product of all numbers.

# %%
from functools import reduce

result = reduce(lambda x,y: x*y, [1,2,3,4,5])

print(result)
# Out:
# 120

# %% [markdown]
# ## 13.Sort the following list according to age.

# %%
students = [
("Ram",22),
("Amit",19),
("Neha",25),
("Raj",20)
]
result = sorted(students, key=lambda x:x[1])

result
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %% [markdown]
# ## 14.Sort the following dictionary by values.

# %%
marks = {
"A":80,
"B":95,
"C":70,
"D":88
}
#result = sorted(marks, key=lambda x:x[1])
result = sorted(marks.items(),key=lambda x: x[1])
result
# Out:
# [('C', 70), ('A', 80), ('D', 88), ('B', 95)]

# %% [markdown]
# ## 15.Find the longest string using lambda.

# %%
fruit = ["apple","banana","kiwi","watermelon"]
largest = max(fruit, key=lambda x: x)
print(largest)
# Out:
# watermelon

# %% [markdown]
# ## 16.Use lambda with max() to find the student having the highest marks.

# %%
students = [("Ram",85),("Amit",91),("Neha",78)]
largest = max(students, key=lambda x: x[1])
print(largest)
# Out:
# ('Amit', 91)

# %% [markdown]
# ## 17.Use lambda with min() to find the employee with the lowest salary.

# %%
employees = [
("A",35000),
("B",42000),
("C",28000)
]

smallest = min(employees, key=lambda x: x[1])

print(smallest)
# Out:
# ('C', 28000)

# %% [markdown]
# ## 18.Use map() with lambda to convert all names into uppercase.

# %%
name =["ram","amit","neha"]
case = list(map(lambda s : s.upper(),name))
case
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %% [markdown]
# ## 19.Filter all words having length greater than 5.

# %%
fruit =["apple","banana","kiwi","orange","grapes"]
greater =list(filter(lambda f: len(f) > 5,fruit))
greater
# Out:
# ['banana', 'orange', 'grapes']

# %% [markdown]
# ## 20.Sort tuples based on the second element.

# %%
element =[(1,5),(3,2),(2,8),(4,1)]
result = sorted(element,key=lambda x: x[1])
result
# Out:
# [(4, 1), (3, 2), (1, 5), (2, 8)]

# %% [markdown]
# ## 21.Sort the following list of dictionaries based on salary.

# %%
employees = [{"name":"Ram","salary":50000},{"name":"Amit","salary":65000},{"name":"Neha","salary":45000}]
result = sorted(employees,key=lambda x: x["salary"])
result
# Out:
# [{'name': 'Neha', 'salary': 45000},
#  {'name': 'Ram', 'salary': 50000},
#  {'name': 'Amit', 'salary': 65000}]

# %% [markdown]
# ## 22.Sort students by marks descending and name ascending.

# %%
students = [("Ram",90),("Amit",90),("Neha",85),("Raj",95)]
#result = sorted(students,key=lambda x: x[1], reserse=True)
order = sorted(students, key=lambda x: x[1],reverse = True)
print(order)
order = sorted(students, key=lambda x: x)
print(order)
print(order)
# Out:
# [('Raj', 95), ('Ram', 90), ('Amit', 90), ('Neha', 85)]
# [('Amit', 90), ('Neha', 85), ('Raj', 95), ('Ram', 90)]
# [('Amit', 90), ('Neha', 85), ('Raj', 95), ('Ram', 90)]

# %% [markdown]
# ## 23.Use nested lambda to multiply two numbers.
# Expected usage:
# multiply = ?
# print(multiply(5)(10))
# Output:
# 50

# %%
multiply = lambda x: lambda y: x * y

print(multiply(5)(10))
# Out:
# 50

# %% [markdown]
# ## 24.Create a lambda that returns another lambda for exponentiation.
# Example
# square = power(2)
#
# print(square(6))
# Output
# 36

# %%
square = lambda x: lambda y: x **y

print(square(5)(2))
# Out:
# 25

# %% [markdown]
# ## 25.Using lambda and filter(), remove all negative numbers.
# [-5,10,-3,8,0,-1,20]

# %%
num =[-5,10,-3,8,0,-1,20]

result = list(filter(lambda x: x >= 0,num))
result
# Out:
# [10, 8, 0, 20]

# %% [markdown]
# ## 26.Using lambda and map(), replace every odd number by its square while leaving even
# numbers unchanged.
# [1,2,3,4,5,6]
# Expected Output
# [1,2,9,4,25,6]

# %%
num = [1,2,3,4,5,6]

result = list(map(lambda i :i if i % 2 == 0 else i**2 ,num))
result
# Out:
# [1, 2, 9, 4, 25, 6]

# %% [markdown]
# ## 27.Sort strings based on their last character.
# ["apple","banana","kiwi","grape"]

# %%
fruit =["apple","banana","kiwi","grape"]
#fruit = ["apple","banana","kiwi","watermelon"]
last_alpha = sorted(fruit, key=lambda x: x[-1])
print(last_alpha)
# Out:
# ['banana', 'apple', 'grape', 'kiwi']

# %% [markdown]
# ## 28.Find the second highest salary using lambda.
# employees = [
# ("A",45000),
# ("B",60000),
# ("C",52000),
# ("D",75000)
# ]

# %%
employees = [ ("A",45000), ("B",60000), ("C",52000), ("D",75000) ]
largest = sorted(employees, key=lambda x: x[1])
print(largest)
print(largest[2])
# Out:
# [('A', 45000), ('C', 52000), ('B', 60000), ('D', 75000)]
# ('B', 60000)

# %% [markdown]
# ## 29.Sort a list of dictionaries by age ascending and then salary descending.
# employees = [
# {"name":"Ram","age":25,"salary":50000},
# {"name":"Amit","age":25,"salary":60000},
# {"name":"Neha","age":23,"salary":45000},
# {"name":"Raj","age":27,"salary":55000}
# ]

# %%
employees = [ {"name":"Ram","age":25,"salary":50000}, {"name":"Amit","age":25,"salary":60000},
              {"name":"Neha","age":23,"salary":45000}, {"name":"Raj","age":27,"salary":55000}]
order = sorted(employees, key=lambda x: x[1])
print(order)
order = sorted(employees, key=lambda x: x[2],reverse = True)
print(order)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 3
#       1 employees = [ {"name":"Ram","age":25,"salary":50000}, {"name":"Amit","age":25,"salary":60000},
#       2               {"name":"Neha","age":23,"salary":45000}, {"name":"Raj","age":27,"salary":55000}]
# ----> 3 order = sorted(employees, key=lambda x: x[1])
#       4 print(order)
#       5 order = sorted(employees, key=lambda x: x[2],reverse = True)
#
# Cell In[112], line 3, in <lambda>(x)
#       1 employees = [ {"name":"Ram","age":25,"salary":50000}, {"name":"Amit","age":25,"salary":60000},
#       2               {"name":"Neha","age":23,"salary":45000}, {"name":"Raj","age":27,"salary":55000}]
# ----> 3 order = sorted(employees, key=lambda x: x[1])
#       4 print(order)
#       5 order = sorted(employees, key=lambda x: x[2],reverse = True)
#
# KeyError: 1
